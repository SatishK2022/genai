# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-3.5-turbo")

# %%
text = "My name is Satish. My email is satishkumar.starx@gmail.com and my age is 22."

res = llm.invoke(f"Only give me the name, email and age from the text in json format : {text}")
print(res.content)
# Out:
# {
#   "name": "Satish",
#   "email": "satishkumar.starx@gmail.com",
#   "age": 22
# }

# %% [markdown]
# ### Structured Output

# %%
from pydantic import BaseModel, Field
from typing import List

class ResponseStructure(BaseModel):
    name: str = Field(description="Full name")
    email: str = Field(description="Email Address")
    age: int = Field(description="Age ")

structured_llm = llm.with_structured_output(ResponseStructure)

text = "My name is Satish. My email is satishkumar.starx@gmail.com and my age is 22."

res = structured_llm.invoke(f"Only give me the name, email and age from the text in json format : {text}")
res.model_dump()
# Out:
# /home/satish-kumar/Desktop/genai/genai-tut/env/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:2210: UserWarning: Cannot use method='json_schema' with model gpt-3.5-turbo since it doesn't support OpenAI's Structured Output API. You can see supported models here: https://platform.openai.com/docs/guides/structured-outputs#supported-models. To fix this warning, set `method='function_calling'. Overriding to method='function_calling'.
#   warnings.warn(
# {'name': 'Satish', 'email': 'satishkumar.starx@gmail.com', 'age': 22}

# %%
class Movies(BaseModel):
    title: str = Field(description="Movie Title")
    year: int = Field(description="Movie Year")

class AllMovies(BaseModel):
    movies: List[Movies]

movie_llm = llm.with_structured_output(AllMovies)
res = movie_llm.invoke("Give me 3 recent Movie")
res.model_dump()
# Out:
# /home/satish-kumar/Desktop/genai/genai-tut/env/lib/python3.12/site-packages/langchain_openai/chat_models/base.py:2210: UserWarning: Cannot use method='json_schema' with model gpt-3.5-turbo since it doesn't support OpenAI's Structured Output API. You can see supported models here: https://platform.openai.com/docs/guides/structured-outputs#supported-models. To fix this warning, set `method='function_calling'. Overriding to method='function_calling'.
#   warnings.warn(
# {'movies': [{'title': 'The Matrix Resurrections', 'year': 2021},
#   {'title': 'Spider-Man: No Way Home', 'year': 2021},
#   {'title': 'Dune', 'year': 2021}]}
