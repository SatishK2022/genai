# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import ChatPromptTemplate

llm = ChatGroq(model="llama-3.3-70b-versatile", streaming=True)

# %%
prompt = ChatPromptTemplate.from_messages([
    {"role": "system", "content": "You are a GEN AI Developer."},
    {"role": "user", "content": "{query}"},
])

chains = prompt | llm

# %%
response = chains.stream({ "query": "Explain GenAI"})

response

for chunk in response:
    print(chunk.content, end="")
# Out:
# As a GEN AI Developer, I'm excited to explain what GEN AI is and its significance in the field of artificial intelligence.
#
# **What is GEN AI?**
#
# GEN AI stands for Generalized Artificial Intelligence, but in the context of AI development, GEN AI refers to a type of AI model that can generate human-like text, images, or other forms of content based on a given prompt or input. GEN AI models are designed to be highly versatile and can perform a wide range of tasks, such as:
#
# 1. Text generation: GEN AI models can generate coherent and context-specific text, including articles, stories, conversations, and more.
# 2. Image generation: GEN AI models can generate images, such as photos, artwork, or graphics, based on a given prompt or input.
# 3. Code generation: GEN AI models can generate code in various programming languages, such as Python, Java, or C++.
# 4. Music generation: GEN AI models can generate music, such as melodies, harmonies, or entire compositions.
#
# **How does GEN AI work?**
#
# GEN AI models are typically based on deep learning architectures, such as transformer models or generative adversarial networks (GANs). These models are trained on large datasets of text, images, or other forms of content, which allows them to learn patterns and relationships within the data.
#
# When a user provides a prompt or input, the GEN AI model uses this information to generate a response or output. The model's output is based on the patterns and relationships it has learned from the training data, as well as the specific input or prompt provided by the user.
#
# **Characteristics of GEN AI**
#
# GEN AI models have several key characteristics that distinguish them from other types of AI models:
#
# 1. **Generativity**: GEN AI models can generate new and original content, rather than simply reproducing existing data.
# 2. **Versatility**: GEN AI models can perform a wide range of tasks and can be fine-tuned for specific applications or domains.
# 3. **Contextual understanding**: GEN AI models can understand the context of a given prompt or input and generate responses that are relevant and coherent.
# 4. **Creativity**: GEN AI models can generate novel and creative outputs, such as artwork, music, or stories.
#
# **Applications of GEN AI**
#
# GEN AI has a wide range of applications, including:
#
# 1. **Content creation**: GEN AI models can be used to generate high-quality content, such as articles, social media posts, or product descriptions.
# 2. **Art and design**: GEN AI models can be used to generate original artwork, graphics, or music.
# 3. **Chatbots and virtual assistants**: GEN AI models can be used to power chatbots and virtual assistants that can have natural-sounding conversations with users.
# 4. **Language translation**: GEN AI models can be used to translate text from one language to another.
#
# Overall, GEN AI has the potential to revolutionize a wide range of industries and applications, from content creation and art to customer service and language translation. As a GEN AI Developer, I'm excited to explore the possibilities of this technology and push the boundaries of what is possible with AI.
